# %%
import pandas as pd

list1 = ['ab','ddd','dafe']
list2 = ['dfadfa','ddd','dafe','efe','dfadafe']
test_df = pd.DataFrame({'List 1':list1, 'List 2':list2})
test_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Arthur/Developer/Trading/draftpad.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/Users/Arthur/Developer/Trading/draftpad.ipynb#ch0000000?line=2'>3</a> list1 = ['ab','ddd','dafe']
#       <a href='vscode-notebook-cell:/Users/Arthur/Developer/Trading/draftpad.ipynb#ch0000000?line=3'>4</a> list2 = ['dfadfa','ddd','dafe','efe','dfadafe']
# ----> <a href='vscode-notebook-cell:/Users/Arthur/Developer/Trading/draftpad.ipynb#ch0000000?line=4'>5</a> test_df = pd.DataFrame({'List 1':list1, 'List 2':list2})
#       <a href='vscode-notebook-cell:/Users/Arthur/Developer/Trading/draftpad.ipynb#ch0000000?line=5'>6</a> test_df
#
# File ~/Developer/Trading/venv/lib/python3.10/site-packages/pandas/core/frame.py:637, in DataFrame.__init__(self, data, index, columns, dtype, copy)
# ...

# %%
df = pd.read_csv('~/Desktop/tracker.csv')
df
# Out:
#           Date                                         New Symbol  \
# 0   2021-11-28  ['CYRN.csv', 'MRVL.csv', 'SWTX.csv', 'BCACU.cs...
# 1   2021-11-29  ['PBAXW.csv', 'SAMAW.csv', 'HWKZ+.csv', 'LCW+....
# 2   2021-11-30  ['BAFN.csv', 'OP.csv', 'FRC-N.csv', 'IXAQ.csv'...
# 3   2021-12-01  ['ENER.csv', 'YUMY.csv', 'CDROW.csv', 'CTV+.cs...
# 4   2021-12-02  ['SGII.csv', 'GRAB.csv', 'FBTC.csv', 'NFTZ.csv...
# 5   2021-12-03  ['BIOSU.csv', 'HGTY+.csv', 'AVACW.csv', 'CELZ....
# 6   2021-12-06  ['NEH.csv', 'PIII.csv', 'RILYG.csv', 'GCA.csv'...
# 7   2021-12-06  ['BZFD.csv', 'IMPPP.csv', 'PEARW.csv', 'IMPP.c...
# 8   2021-12-08  ['MEME.csv', 'GLLIU.csv', 'LION.csv', 'ALM.csv...
# 9   2021-12-08  ['ROC.csv', 'BBAI+.csv', 'THAC.csv', 'CINGW.cs...
# 10  2021-12-09  ['BOXD.csv', 'WTAI.csv', 'ENTFW.csv', 'FHLTW.c...
# 11  2021-12-10                                                 []
# 12  2021-12-10  ['AXH+.csv', 'GFGDU.csv', 'FRBNU.csv', 'VRE.cs...
# ...

# %%
import multiprocessing as mp
os.cpu_count()
# Out:
# 10

# %%
import os
os.cpu_count()
# Out:
# 10
