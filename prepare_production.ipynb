# %%
import os
import Paths
import datetime
import pandas as pd
import utilities
import time_utilities

# %%
"""
Only for initial production run.
"""
# Out:
# '\nOnly for initial production run.\n'

# %%
# Inital update folder:
update_data_folder = "./Data/Daily/Updates/2021-11-28"

# %%
# get all files under a folder and store them into list
p_file_list = [f for f in os.listdir(Paths.Daily_Data_Production_Folder) if f.endswith('.csv')]
len(p_file_list)
# Out:
# 12197

# %%
u_file_list = [f for f in os.listdir('./Data/Daily/Updates/2021-11-28') if f.endswith('.csv')]
len(u_file_list)
# Out:
# 12197

# %%
# get files in p_file_list but not in u_file_list
p_file_list_diff = [f for f in u_file_list if f not in p_file_list]
p_file_list_diff
# Out:
# []

# %%
# Test if every item in o_file_list is in p_file_list
for f in p_file_list:
	if f not in o_file_list:
		print(f)

# %%
import os
updates_folder = "./Data/Daily/Updates/2021-11-28"
update_files_path = [os.path.join(updates_folder, f) for f in os.listdir(updates_folder) if f.endswith('.csv')]
update_files = [os.path.basename(f) for f in update_files_path]
update_symbols = [os.path.splitext(f)[0] for f in [os.path.basename(f) for f in update_files_path]]
update_symbols
# Out:
# ['RIV',
#  'ANTE',
#  'BRZE',
#  'CSCO',
#  'PRI',
#  'INDIW',
#  'DTEWI',
#  'STL-A',
#  'ARGU',
#  'NZF',
#  'K25',
#  'TYRA',
#  'AIRC',
#  'HLNE',
#  'DSCF',
#  'UNT',
#  'SPXB',
#  'GXIIU',
#  'COLIU',
#  'HUBS',
#  'PCG22',
#  'GPL',
#  'AFTR.U',
#  'SBEA',
#  'VCAR',
#  'SBGI',
#  'HTLFP',
#  'UFCS',
#  'TEAF',
#  'RJZ',
#  'QDEU',
#  'C-P.CL',
#  'GFED',
#  'DRH-A',
#  'AIRT',
#  'SITC',
#  'TLIS',
#  'T29C',
#  'MCK29',
#  'TLGA+',
#  'NXN',
#  'SVSVW',
#  'BNY',
#  'SPXU',
#  'NUVB+',
#  'FRC-C.CL',
#  'PPA',
#  'BUD38',
#  'RHE',
#  'SBEV',
#  'MDCP',
#  'LILM',
#  'TGVCW',
#  'ISSC',
#  'SORRTWI',
#  'KNDI',
#  'EFT',
#  'USTB',
#  'TRNS',
#  'XSHD',
#  'BBSA',
#  'RDW+',
#  'PTOCU',
#  'BCI',
#  'ACII.U',
#  'BBRE',
#  'NTZ',
#  'LBPH',
#  'LYFE',
#  'AEIS',
#  'UAL',
#  'NCWI',
#  'TROW',
#  'LEVYW',
#  'ISRG',
#  'EGP',
#  'TRND',
#  'GDRX',
#  'AUBAP',
#  'BDCPRB',
#  'BTI29',
#  'QDIV',
#  'VPCBU',
#  'ISO',
#  'CLNYPRJ',
#  'EFC',
#  'EEX',
#  'BP27C',
#  'CAI-A',
# ...
